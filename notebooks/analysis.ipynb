# %% [markdown]
# # Stock Tracker Notebook
#
# This is a new notebook for your stock tracking analysis.

# %%
from massive import RESTClient

client = RESTClient("MX8dLTzDgcUHHLh6GNE12iOzitcS_HCH")

items = []
for item in client.list_benzinga_news_v2(
    limit="100",
    sort="published.desc",
):
    items.append(item)

print(items)

# %%
import yfinance as yf
stock = yf.Ticker("NFLX")

ES = stock.get_earnings_dates()
ES.head()
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2026-01-20 16:00:00-05:00          0.55           NaN          NaN
# 2025-10-21 16:00:00-04:00          0.70          0.59       -15.79
# 2025-07-17 16:00:00-04:00          0.71          0.72         1.95
# 2025-04-17 16:00:00-04:00          0.57          0.66        16.37
# 2025-01-21 16:00:00-05:00          0.42          0.43         1.41

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 transcripts = ticker.earning_call_transcripts()
#
# NameError: name 'ticker' is not defined

# %%
import defeatbeta_api
from defeatbeta_api.data.ticker import Ticker
# Out:
# [nltk_data] Error loading punkt_tab: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1032)>
# ______      __           _    ______      _
# |  _  \    / _|         | |   | ___ \    | |
# | | | |___| |_ ___  __ _| |_  | |_/ / ___| |_ __ _
# | | | / _ \  _/ _ \/ _` | __| | ___ \/ _ \ __/ _` |
# | |/ /  __/ ||  __/ (_| | |_  | |_/ /  __/ || (_| |
# |___/ \___|_| \___|\__,_|\__| \____/ \___|\__\__,_|
# 📈:: Data Update Time ::	2025-12-07 ::
# 📈:: Software Version ::	0.0.27      ::

# %%
ticker = Ticker('TSLA')
transcripts = ticker.earning_call_transcripts()
transcripts.get_transcripts_list()
# Out:
#    symbol  fiscal_year  fiscal_quarter report_date  \
# 0    TSLA         2011               2  2011-08-03
# 1    TSLA         2011               3  2011-11-03
# 2    TSLA         2011               4  2012-02-16
# 3    TSLA         2012               1  2012-05-09
# 4    TSLA         2012               2  2012-07-25
# 5    TSLA         2012               3  2012-11-05
# 6    TSLA         2012               4  2013-02-20
# 7    TSLA         2013               1  2013-05-08
# 8    TSLA         2013               2  2013-08-07
# 9    TSLA         2013               3  2013-11-05
# 10   TSLA         2013               4  2014-02-19
# 11   TSLA         2014               1  2014-05-08
# 12   TSLA         2014               2  2014-08-01
# 13   TSLA         2014               3  2014-11-05
# 14   TSLA         2014               4  2015-02-12
# 15   TSLA         2015               1  2015-05-05
# 16   TSLA         2015               2  2015-07-30
# ...

# %%
import yfinance as yf

ticker = yf.Ticker("MSFT")

# Get upcoming and historic earnings dates
print(ticker.earnings_dates) 

# Get the Income Statement (Revenue, Net Income, etc.)
print(ticker.income_stmt)
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2026-01-28 16:00:00-05:00          3.86           NaN          NaN
# 2025-10-29 16:00:00-04:00          3.66          3.72         1.59
# 2025-07-30 16:00:00-04:00          3.38          3.65         8.09
# 2025-04-30 16:00:00-04:00          3.22          3.46         7.40
# 2025-01-29 16:00:00-05:00          3.10          3.23         4.06
# 2024-10-30 16:00:00-04:00          3.11          3.30         6.25
# 2024-07-30 16:00:00-04:00          2.94          2.95         0.23
# 2024-04-25 16:00:00-04:00          2.84          2.94         3.40
# 2024-01-30 16:00:00-05:00          2.77          2.93         5.83
# 2023-10-24 16:00:00-04:00          2.65          2.99        12.85
# 2023-07-25 16:00:00-04:00          2.55          2.69         5.45
# 2023-04-25 16:00:00-04:00          2.23          2.45         9.77
# 2023-01-24 16:00:00-05:00          2.32          2.32         0.21
# ...
